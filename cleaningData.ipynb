# %%
import pandas 
import matplotlib
import seaborn

import pandas as pd
df = pd.read_csv("vehicles_dataset.csv")

#import pandas as pd
#df = pd.read_csv("RCL_FROM_2020_2024.csv")

# %%
pd.set_option('display.max_columns', None)

#Read Car List dataframe and show maximum columns
 
df_CarList = pd.read_csv("vehicles_dataset.csv")
df_CarList.info(max_cols=20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1002 entries, 0 to 1001
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            1002 non-null   object
#  1   description     946 non-null    object
#  2   make            1002 non-null   object
#  3   model           1002 non-null   object
#  4   type            1002 non-null   object
#  5   year            1002 non-null   int64
#  6   price           979 non-null    float64
#  7   engine          1000 non-null   object
#  8   cylinders       897 non-null    float64
#  9   fuel            995 non-null    object
#  10  mileage         968 non-null    float64
#  11  transmission    1000 non-null   object
#  12  trim            1001 non-null   object
#  13  body            999 non-null    object
#  14  doors           995 non-null    float64
#  15  exterior_color  997 non-null    object
#  16  interior_color  964 non-null    object
#  17  drivetrain      1002 non-null   object
# dtypes: float64(4), int64(1), object(13)
# memory usage: 141.0+ KB

# %%
df_CarList = df_CarList[df_CarList['year'] == 2024]
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# Find Missing values

# %%
df_CarList[df_CarList.isnull().any(axis=1)]
# Out:
#                                            name  \
# 2                      2024 GMC Yukon XL Denali
# 8            2024 Hyundai Tucson Hybrid Limited
# 14                 2024 Chevrolet Blazer EV 2LT
# 23                      2024 GMC Terrain Denali
# 27             2024 Chrysler Pacifica Touring-L
# ..                                          ...
# 977               2024 Kia Sportage SX-Prestige
# 978                           2024 Kia EV6 Wind
# 980                          2024 Kia Forte LXS
# 985  2024 Hyundai Tucson Hybrid SEL Convenience
# 987  2024 Hyundai Tucson Hybrid SEL Convenience
#
#                                            description       make  \
# 2                                                  NaN        GMC
# 8                                                  NaN    Hyundai
# 14   \n      \n        Sterling Gray Metallic 2024 ...  Chevrolet
# 23                                                 NaN        GMC
# 27   \n      \n        $750 off MSRP! 2024 Chrysler...   Chrysler
# ..                                                 ...        ...
# 977                                                NaN        Kia
# 978  Aurora Black Pearl 2024 Kia EV6 Wind AWD 1-Spe...        Kia
# 980  \n      \n        2024 Kia Forte Steel Gray LX...        Kia
# 985                                                NaN    Hyundai
# 987                                                NaN    Hyundai
#
#              model type  year    price  \
# 2         Yukon XL  New  2024  96410.0
# 8    Tucson Hybrid  New  2024  42230.0
# 14       Blazer EV  New  2024  51695.0
# 23         Terrain  New  2024  44120.0
# 27        Pacifica  New  2024  48705.0
# ..             ...  ...   ...      ...
# 977       Sportage  New  2024  35195.0
# 978            EV6  New  2024  43439.0
# 980          Forte  New  2024  21070.0
# 985  Tucson Hybrid  New  2024  37220.0
# 987  Tucson Hybrid  New  2024  37309.0
#
#                                                 engine  cylinders      fuel  \
# 2    6.2L V-8 gasoline direct injection, variable v...        8.0  Gasoline
# 8                            16V GDI DOHC Turbo Hybrid        4.0    Hybrid
# 14                                                   c        NaN  Electric
# 23   4 gasoline direct injection, DOHC, variable va...        4.0  Gasoline
# 27                                       24V MPFI DOHC        6.0  Gasoline
# ..                                                 ...        ...       ...
# 977                                       16V PDI DOHC        4.0  Gasoline
# 978                                                  c        NaN  Electric
# 980                                      16V MPFI DOHC        4.0  Gasoline
# 985                          16V GDI DOHC Turbo Hybrid        4.0    Hybrid
# 987                          16V GDI DOHC Turbo Hybrid        4.0    Hybrid
#
#      mileage       transmission             trim           body  doors  \
# 2        0.0          Automatic           Denali            SUV    4.0
# 8        5.0  6-Speed Automatic          Limited            SUV    4.0
# 14       4.0  1-Speed Automatic              2LT            SUV    4.0
# 23       0.0          Automatic           Denali            SUV    4.0
# 27       NaN  9-Speed Automatic        Touring-L  Passenger Van    4.0
# ..       ...                ...              ...            ...    ...
# 977     10.0  8-Speed Automatic      SX-Prestige            SUV    4.0
# 978     14.0          Automatic             Wind            SUV    4.0
# 980      NaN      Automatic CVT              LXS          Sedan    4.0
# 985      5.0  6-Speed Automatic  SEL Convenience            SUV    4.0
# 987      5.0  6-Speed Automatic  SEL Convenience            SUV    4.0
#
#              exterior_color    interior_color         drivetrain
# 2              Summit White  Teak/Light Shale   Four-wheel Drive
# 8               White Pearl             Black    All-wheel Drive
# 14   Sterling Gray Metallic             Black    All-wheel Drive
# 23                    Ebony           Jet Blk    All-wheel Drive
# 27            Diamond Black             Black    All-wheel Drive
# ..                      ...               ...                ...
# 977             Ebony Black             Black  Front-wheel Drive
# 978      Aurora Black Pearl             Black    All-wheel Drive
# 980              Steel Gray             Black  Front-wheel Drive
# 985                Deep Sea              Gray    All-wheel Drive
# 987             Amazon Gray             Black    All-wheel Drive
#
# [232 rows x 18 columns]

# %% [markdown]
# <font size="4">We have 252 rows of missing values. Lets clean this up by removing uneccessary columns and remove rows with NaN values

# %%
#df_CarList.to_csv('vehicles_dataset.csv', index=False) #Saves cleaned data to a new file

# %%
df_CarList.drop(columns=["description","fuel","type","engine","interior_color","exterior_color","mileage","doors"], inplace=True)

# %%
df_CarList.drop_duplicates()
# Out:
#                                                 name           make  \
# 0                       2024 Jeep Wagoneer Series II           Jeep
# 1                    2024 Jeep Grand Cherokee Laredo           Jeep
# 2                           2024 GMC Yukon XL Denali            GMC
# 4                              2024 RAM 3500 Laramie            RAM
# 5                        2024 Nissan Murano Platinum         Nissan
# ...                                              ...            ...
# 996                          2024 RAM 2500 Tradesman            RAM
# 997   2024 Mercedes-Benz Sprinter 2500 Standard Roof  Mercedes-Benz
# 999                          2024 Jeep Wagoneer Base           Jeep
# 1000           2024 Nissan Murano SV Intelligent AWD         Nissan
# 1001                2024 Chevrolet Silverado 2500 WT      Chevrolet
#
#                model  year    price  cylinders       transmission  \
# 0           Wagoneer  2024  74600.0        6.0  8-Speed Automatic
# 1     Grand Cherokee  2024  50170.0        6.0  8-Speed Automatic
# 2           Yukon XL  2024  96410.0        8.0          Automatic
# 4               3500  2024  81663.0        6.0  6-Speed Automatic
# 5             Murano  2024  46000.0        6.0      Automatic CVT
# ...              ...   ...      ...        ...                ...
# 996             2500  2024  69315.0        6.0          Automatic
# 997    Sprinter 2500  2024  59037.0        4.0  9-Speed Automatic
# 999         Wagoneer  2024  69085.0        6.0  8-Speed Automatic
# 1000          Murano  2024  43495.0        6.0          Automatic
# 1001  Silverado 2500  2024  48995.0        8.0          Automatic
#
#                     trim          body        drivetrain
# 0              Series II           SUV  Four-wheel Drive
# 1                 Laredo           SUV  Four-wheel Drive
# 2                 Denali           SUV  Four-wheel Drive
# 4                Laramie  Pickup Truck  Four-wheel Drive
# 5               Platinum           SUV   All-wheel Drive
# ...                  ...           ...               ...
# 996            Tradesman  Pickup Truck  Four-wheel Drive
# 997        Standard Roof     Cargo Van  Rear-wheel Drive
# 999                 Base           SUV  Four-wheel Drive
# 1000  SV Intelligent AWD           SUV   All-wheel Drive
# 1001                  WT  Pickup Truck  Rear-wheel Drive
#
# [824 rows x 10 columns]

# %%
#df.isnull().sum()
df_CarList.isnull().sum()
# Out:
# name             0
# make             0
# model            0
# year             0
# price           21
# cylinders       95
# transmission     2
# trim             0
# body             3
# drivetrain       0
# dtype: int64

# %%
#Find missing values again which resulted in 130 this time
df_CarList[df_CarList.isnull().any(axis=1)]
# Out:
#                                                name       make  \
# 14                     2024 Chevrolet Blazer EV 2LT  Chevrolet
# 28                     2024 Chevrolet Blazer EV 2LT  Chevrolet
# 33                                  2024 Kia EV6 GT        Kia
# 35                 2024 Ford Mustang Mach-E Premium       Ford
# 49           2024 Hyundai IONIQ 5 SE Standard Range    Hyundai
# ..                                              ...        ...
# 940  2024 Ford Transit-350 148 WB Medium Roof Cargo       Ford
# 941                         2024 Hyundai IONIQ 5 SE    Hyundai
# 943                          2024 Ford Edge ST-Line       Ford
# 944                               2024 Kia EV6 Wind        Kia
# 978                               2024 Kia EV6 Wind        Kia
#
#               model  year    price  cylinders       transmission  \
# 14        Blazer EV  2024  51695.0        NaN  1-Speed Automatic
# 28        Blazer EV  2024  52190.0        NaN  1-Speed Automatic
# 33              EV6  2024  49820.0        NaN          Automatic
# 35   Mustang Mach-E  2024  47790.0        NaN  1-Speed Automatic
# 49          IONIQ 5  2024  44195.0        NaN  1-Speed Automatic
# ..              ...   ...      ...        ...                ...
# 940     Transit-350  2024  52530.0        6.0                NaN
# 941         IONIQ 5  2024  38201.0        NaN          Automatic
# 943            Edge  2024      NaN        4.0  8-Speed Automatic
# 944             EV6  2024  41528.0        NaN          Automatic
# 978             EV6  2024  43439.0        NaN          Automatic
#
#                          trim       body        drivetrain
# 14                        2LT        SUV   All-wheel Drive
# 28                        2LT        SUV   All-wheel Drive
# 33                         GT        SUV   All-wheel Drive
# 35                    Premium        SUV   All-wheel Drive
# 49          SE Standard Range        SUV  Rear-wheel Drive
# ..                        ...        ...               ...
# 940  148 WB Medium Roof Cargo  Cargo Van  Rear-wheel Drive
# 941                        SE        SUV  Rear-wheel Drive
# 943                   ST-Line        SUV   All-wheel Drive
# 944                      Wind        SUV   All-wheel Drive
# 978                      Wind        SUV   All-wheel Drive
#
# [117 rows x 10 columns]

# %%
#Replacing NaN vaules in cyclinder with 'Eletric' for the Electric Vehicles
df_CarList['cylinders']= df_CarList['cylinders'].fillna("Electric")

#Filling missing values in transmiddion column
df_CarList['transmission']=df_CarList['transmission'].fillna("Automatic")

#Adding SUV to NaNs in the column 'body'
df_CarList['body']=df_CarList['body'].fillna("SUV")

#Recheck missing values
df_CarList[df_CarList.isnull().any(axis=1)]
# Out:
#                                        name           make           model  \
# 142  2024 Mercedes-Benz EQS 450 Base 4MATIC  Mercedes-Benz         EQS 450
# 248              2024 Dodge Durango Pursuit          Dodge         Durango
# 328  2024 Mercedes-Benz EQS 450 Base 4MATIC  Mercedes-Benz         EQS 450
# 372  2024 Mercedes-Benz EQS 450 Base 4MATIC  Mercedes-Benz         EQS 450
# 417                 2024 RAM 3500 Tradesman            RAM            3500
# 443               2024 Jeep Compass Limited           Jeep         Compass
# 500                       2024 Ford Edge SE           Ford            Edge
# 506              2024 Dodge Durango Pursuit          Dodge         Durango
# 536                    2024 Dodge Hornet GT          Dodge          Hornet
# 541                  2024 RAM 3500 Big Horn            RAM            3500
# 627                   2024 Dodge Hornet R/T          Dodge          Hornet
# 678    2024 Hyundai Santa Cruz 2.5T Limited        Hyundai      Santa Cruz
# 683  2024 Mercedes-Benz GLE 350 Base 4MATIC  Mercedes-Benz         GLE 350
# 704                  2024 Ford Edge ST-Line           Ford            Edge
# 779                       2024 Ford Edge SE           Ford            Edge
# 809         2024 Jeep Grand Cherokee Laredo           Jeep  Grand Cherokee
# 811                          2024 BMW 530 i            BMW             530
# 859                   2024 Dodge Hornet R/T          Dodge          Hornet
# 876                       2024 Ford Edge SE           Ford            Edge
# 937                    2024 Dodge Hornet GT          Dodge          Hornet
# 943                  2024 Ford Edge ST-Line           Ford            Edge
#
#      year  price cylinders                       transmission          trim  \
# 142  2024    NaN  Electric                          Automatic   Base 4MATIC
# 248  2024    NaN       8.0                  8-Speed Automatic       Pursuit
# 328  2024    NaN  Electric                          Automatic   Base 4MATIC
# 372  2024    NaN  Electric                          Automatic   Base 4MATIC
# 417  2024    NaN       8.0                  8-Speed Automatic     Tradesman
# 443  2024    NaN       4.0                  8-Speed Automatic       Limited
# 500  2024    NaN       4.0                  8-Speed Automatic            SE
# 506  2024    NaN       6.0                  8-Speed Automatic       Pursuit
# 536  2024    NaN       4.0                  9-Speed Automatic            GT
# 541  2024    NaN       6.0                  6-Speed Automatic      Big Horn
# 627  2024    NaN       4.0                  6-Speed Automatic           R/T
# 678  2024    NaN       4.0  8-Speed Automatic with Auto-Shift  2.5T Limited
# 683  2024    NaN       4.0                  9-Speed Automatic   Base 4MATIC
# 704  2024    NaN       4.0                  8-Speed Automatic       ST-Line
# 779  2024    NaN       4.0                  8-Speed Automatic            SE
# 809  2024    NaN       6.0                  8-Speed Automatic        Laredo
# 811  2024    NaN       4.0                  8-Speed Automatic             i
# 859  2024    NaN       4.0                  6-Speed Automatic           R/T
# 876  2024    NaN       4.0                  8-Speed Automatic            SE
# 937  2024    NaN       4.0                  9-Speed Automatic            GT
# 943  2024    NaN       4.0                  8-Speed Automatic       ST-Line
#
#              body        drivetrain
# 142         Sedan   All-wheel Drive
# 248           SUV   All-wheel Drive
# 328         Sedan   All-wheel Drive
# 372         Sedan   All-wheel Drive
# 417  Pickup Truck  Four-wheel Drive
# 443           SUV  Four-wheel Drive
# 500           SUV   All-wheel Drive
# 506           SUV   All-wheel Drive
# 536           SUV   All-wheel Drive
# 541  Pickup Truck  Four-wheel Drive
# 627           SUV   All-wheel Drive
# 678  Pickup Truck   All-wheel Drive
# 683           SUV   All-wheel Drive
# 704           SUV   All-wheel Drive
# 779           SUV   All-wheel Drive
# 809           SUV  Four-wheel Drive
# 811         Sedan  Rear-wheel Drive
# 859           SUV   All-wheel Drive
# 876           SUV   All-wheel Drive
# 937           SUV   All-wheel Drive
# 943           SUV   All-wheel Drive

# %%
df_CarList['price'] = df_CarList['price'].fillna(df.groupby('model')['price'].transform('mean'))
df_CarList[df_CarList.isnull().any(axis=1)]
# Out:
#                                        name           make    model  year  \
# 683  2024 Mercedes-Benz GLE 350 Base 4MATIC  Mercedes-Benz  GLE 350  2024
# 811                          2024 BMW 530 i            BMW      530  2024
#
#      price cylinders       transmission         trim   body        drivetrain
# 683    NaN       4.0  9-Speed Automatic  Base 4MATIC    SUV   All-wheel Drive
# 811    NaN       4.0  8-Speed Automatic            i  Sedan  Rear-wheel Drive

# %%
df_CarList['price'] = df_CarList['price'].fillna(df.groupby('make')['price'].transform('mean'))
df_CarList[df_CarList.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [name, make, model, year, price, cylinders, transmission, trim, body, drivetrain]
# Index: []

# %%
df_CarList.isnull().sum()
# Out:
# name            0
# make            0
# model           0
# year            0
# price           0
# cylinders       0
# transmission    0
# trim            0
# body            0
# drivetrain      0
# dtype: int64

# %% [markdown]
# <font size="6">Dataset #1 Cleaned!

# %%
df_rcl = pd.read_csv("RCL_FROM_2020_2024.csv")

# %%
pd.set_option('display.max_columns', None)

#Read Car List dataframe and show maximum columns
df_rcl.info(max_cols=20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9463 entries, 0 to 9462
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   NHTSA ID       9463 non-null   object
#  1   DOCUMENT NAME  9463 non-null   object
#  2   MAKE           9463 non-null   object
#  3   MODEL          9463 non-null   object
#  4   MODEL YEAR     9463 non-null   int64
#  5   SUMMARY        9463 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 443.7+ KB

# %% [markdown]
# <font size="4">Grabbing data for only 2024 vehicles, and checking for missing values.

# %%
df_rcl = df_rcl[df_rcl["MODEL YEAR"] == 2024]
df_rcl.reset_index(drop=True, inplace=True)
df_rcl.isnull().sum()
# Out:
# NHTSA ID         0
# DOCUMENT NAME    0
# MAKE             0
# MODEL            0
# MODEL YEAR       0
# SUMMARY          0
# dtype: int64

# %% [markdown]
# <font size="4">Check and remove duplicate lines.

# %%
df_rcl.drop_duplicates()
df_rcl[df_rcl.isnull().any(axis=1)]
print(df_rcl.info)
# Out:
# <bound method DataFrame.info of      NHTSA ID          DOCUMENT NAME                  MAKE     MODEL  \
# 0      22V909  RCONL-22V909-2556.pdf                IC BUS      CESB
# 1      22V909  RCRIT-22V909-1126.pdf                IC BUS      CESB
# 2      23V065  RCONL-23V065-7947.pdf                IC BUS      CESB
# 3      23V065  RCRIT-23V065-4342.pdf                IC BUS      CESB
# 4      23V087  RCONL-23V087-5040.pdf              KENWORTH      T280
# ...       ...                    ...                   ...       ...
# 9458   24V966  RCONL-24V966-6482.pdf  STORYTELLER OVERLAND    MYSTIC
# 9459   24V966   RCMN-24V966-1472.pdf  STORYTELLER OVERLAND   STEALTH
# 9460   24V966  RCONL-24V966-6482.pdf  STORYTELLER OVERLAND   STEALTH
# 9461   24V968  RCONL-24V968-6389.pdf  STORYTELLER OVERLAND  GXV HILT
# 9462   24V968   RCMN-24V968-0243.pdf  STORYTELLER OVERLAND  GXV HILT
#
#       MODEL YEAR                                            SUMMARY
# 0           2024  22527; 02/06/2023; IC Bus; CE - 2022 & 2023; R...
# 1           2024  22527; 02/01/2023; IC bus; CE - 2022 & 2023; R...
# 2           2024  23501; 04/03/2023; IC Bus; 2022 thru 2024 CE, ...
# 3           2024  23501; 04/03/2023; IC Bus; 2022 thru 2024 CE, ...
# 4           2024  Attached letter is the FINAL customer notifica...
# ...          ...                                                ...
# 9458        2024  This is our final Owner Notification Letter, t...
# 9459        2024  This our Dealer Final Notification. This docum...
# 9460        2024  This is our final Owner Notification Letter, t...
# 9461        2024  This is our Final 577 Customer Notification; t...
# 9462        2024  This is our final copy of our Dealer Notificat...
#
# [9463 rows x 6 columns]>

# %% [markdown]
# <font size="4">Remove Semi Trucks. This data is for the purpose of regular non commercial drivers.

# %%
non_vehicles = ("MACK", "KENWORTH", "TOW KING", "MCI", "CUMMINS", "LIGHTING EMOTORS", "SPARTAN FIRE", "AGILITY FUEL SYSTEMS", "MOPAR", "RUGGED LINERS", "ALTEC", "KEYSTONE", "THOMAS BUILT BUSES",
                "CARRIER TRANSICOLD", "PITTSBURGH AUTOMOTIVE", "FREEDMAN", "KZRN", "PJ TRAILERS", "LODE KING", "NEXUS", "TIFFIN", "WINNEBAGO", "NIKOLA", "VINFAST", "HOLIDAY RAMBLER",
                "JAYCO", "HEARTLAND", "PRATT INTERNATIONAL", "CFMOTO", "XOS", "AIRSTREAM", "INDIAN", "WESTERN STAR", "CAN-AM", "MAINTAINER", "NOVA BUS", "THOR MOTOR COACH", "FREIGHTLINER",
                "PETERBILT", "UTILITY TRAILER", "ARCIMOTO", "NEW FLYER", "KIDRON", "LION", "TICO", "SUPER PRODUCTS", "HINO", "AUTOCAR", "TRIPPLE E", "TRIPLE R", "KAWASAKI", "SCHWARZE", 
                "KZRZ", "TRAIL KING", "CRUISER RV", "TEREX", "TEREX ADVANCED", "INTERNATIONAL", "IC BUS", "FCCC", "VERMEER", "FOREST RIVER", "HUSQVARNA", "KTM", "ZERO", "VAN HOOL",
                "FLEETWOOD", "BRUAN AMBULANCE", "FEILD VAN", "STORYTELLER OVERLAND", "KME", "SAFARI CONDO", "FORETRAVEL", "CUMMINS POWER GENERATION", "MITSUBISHI FUSO", "POLESTAR",
                "AKRON BRASS COMPANY", "TEKONSHA", "DANA", "DOMETIC", "DANA", "LIPPERT", "CODE 3", "AC DELCO", "NAPA")

df_rcl = df_rcl[~df_rcl['MAKE'].isin(non_vehicles)]
df_rcl.reset_index(drop=True, inplace=True)

# %%
df_rcl[df_rcl.isnull().any(axis=1)]
print(df_rcl.info)
df_rcl.tail(59)
# Out:
# <bound method DataFrame.info of      NHTSA ID          DOCUMENT NAME   MAKE MODEL  MODEL YEAR  \
# 0      23V173  RCRIT-23V173-6991.pdf  VOLVO   VHD        2024
# 1      23V173  RCRIT-23V173-4613.pdf  VOLVO   VHD        2024
# 2      23V173  RCRIT-23V173-3354.pdf  VOLVO   VHD        2024
# 3      23V173   RCMN-23V173-3463.pdf  VOLVO   VHD        2024
# 4      23V173  RCRIT-23V173-7160.pdf  VOLVO   VHD        2024
# ...       ...                    ...    ...   ...         ...
# 6914   24V962   RCMN-24V962-3806.pdf    KIA   EV9        2024
# 6915   24V962  RCRIT-24V962-7747.pdf    KIA   EV9        2024
# 6916   24V962  RCONL-24V962-1772.pdf    KIA   EV9        2024
# 6917   24V962   RCMN-24V962-3299.pdf    KIA   EV9        2024
# 6918   24V962   RCMN-24V962-3393.pdf    KIA   EV9        2024
#
#                                                 SUMMARY
# 0     On certain trucks, the hub covers on the drive...
# 1     On certain trucks, the hub covers on the drive...
# 2     Volvo has determined that some hub covers, lac...
# 3     On certain trucks, the hub covers on the drive...
# 4     Volvo has determined that some hub covers, lac...
# ...                                                 ...
# 6914  The Q&A contains questions and answers regardi...
# 6915  The Technical Service Bulletin (TSB) lists spe...
# 6916  Owner Letter notifies the customer of the safe...
# 6917  The Dealer Parts & Service Manager letter is t...
# 6918  The Dealer Principal letter is to notify the d...
#
# [6919 rows x 6 columns]>
#      NHTSA ID          DOCUMENT NAME         MAKE                MODEL  \
# 6860   24V923   RMRP-24V923-6850.pdf       SUZUKI                AN400
# 6861   24V923  RCONL-24V923-5669.pdf       SUZUKI                AN400
# 6862   24V923  RCONL-24V923-2628.pdf       SUZUKI                AN400
# 6863   24V923   RCMN-24V923-5168.pdf       SUZUKI                AN400
# 6864   24V923   RCMN-24V923-4336.pdf       SUZUKI                AN400
# 6865   24V923  RMISC-24V923-1762.pdf       SUZUKI                AN400
# 6866   24V923  RMISC-24V923-0057.pdf       SUZUKI                AN400
# 6867   24V923  RMISC-24V923-0825.pdf       SUZUKI                AN400
# 6868   24V923  RCRIT-24V923-6285.pdf       SUZUKI                AN400
# 6869   24V926  RCRIT-24V926-7328.pdf         JEEP       GRAND CHEROKEE
# 6870   24V926  RCONL-24V926-0792.pdf         JEEP       GRAND CHEROKEE
# 6871   24V926   RCMN-24V926-4485.pdf         JEEP       GRAND CHEROKEE
# 6872   24V926  RCONL-24V926-0792.pdf         JEEP     GRAND CHEROKEE L
# 6873   24V926  RCRIT-24V926-7328.pdf         JEEP     GRAND CHEROKEE L
# 6874   24V926   RCMN-24V926-4485.pdf         JEEP     GRAND CHEROKEE L
# 6875   24V938  RCRIT-24V938-3991.pdf        VOLVO               C40BEV
# 6876   24V938  RCRIT-24V938-7979.pdf        VOLVO               C40BEV
# 6877   24V938   RCMN-24V938-1073.pdf        VOLVO               C40BEV
# 6878   24V944   RCMN-24V944-9550.pdf         JEEP       GRAND CHEROKEE
# 6879   24V944  RCRIT-24V944-4967.pdf         JEEP       GRAND CHEROKEE
# 6880   24V944   RCMN-24V944-4122.pdf         JEEP       GRAND CHEROKEE
# 6881   24V944  RCONL-24V944-1143.pdf         JEEP       GRAND CHEROKEE
# 6882   24V944  RCRIT-24V944-4967.pdf         JEEP     GRAND CHEROKEE L
# 6883   24V944   RCMN-24V944-9550.pdf         JEEP     GRAND CHEROKEE L
# 6884   24V944   RCMN-24V944-4122.pdf         JEEP     GRAND CHEROKEE L
# 6885   24V944  RCONL-24V944-1143.pdf         JEEP     GRAND CHEROKEE L
# 6886   24V944  RCONL-24V944-1143.pdf         JEEP       GRAND WAGONEER
# 6887   24V944  RCRIT-24V944-4967.pdf         JEEP       GRAND WAGONEER
# 6888   24V944   RCMN-24V944-9550.pdf         JEEP       GRAND WAGONEER
# 6889   24V944   RCMN-24V944-4122.pdf         JEEP       GRAND WAGONEER
# 6890   24V944   RCMN-24V944-4122.pdf         JEEP             WAGONEER
# 6891   24V944  RCONL-24V944-1143.pdf         JEEP             WAGONEER
# 6892   24V944   RCMN-24V944-9550.pdf         JEEP             WAGONEER
# 6893   24V944  RCRIT-24V944-4967.pdf         JEEP             WAGONEER
# 6894   24V945  RCONL-24V945-0918.pdf  LAMBORGHINI             REVUELTO
# 6895   24V945  RCRIT-24V945-1938.pdf  LAMBORGHINI             REVUELTO
# 6896   24V945   RCMN-24V945-4283.pdf  LAMBORGHINI             REVUELTO
# 6897   24V949  RCONL-24V949-5063.pdf         FORD  F-150 LIGHTNING BEV
# 6898   24V949   RCMN-24V949-6852.pdf         FORD  F-150 LIGHTNING BEV
# 6899   24V949   RCMN-24V949-6179.pdf         FORD  F-150 LIGHTNING BEV
# 6900   24V953   RCMN-24V953-4080.pdf      LINCOLN             NAUTILUS
# 6901   24V953  RIONL-24V953-8768.pdf      LINCOLN             NAUTILUS
# 6902   24V953  RCONL-24V953-2737.pdf      LINCOLN             NAUTILUS
# 6903   24V953   RCMN-24V953-9283.pdf      LINCOLN             NAUTILUS
# 6904   24V954  RMISC-24V954-7770.pdf         FORD               ESCAPE
# 6905   24V954   RCMN-24V954-5599.pdf         FORD               ESCAPE
# 6906   24V954   RCMN-24V954-8927.pdf         FORD               ESCAPE
# 6907   24V954  RIONL-24V954-1052.pdf         FORD               ESCAPE
# 6908   24V954  RIONL-24V954-2080.pdf         FORD               ESCAPE
# 6909   24V954   RCMN-24V954-5599.pdf      LINCOLN              CORSAIR
# 6910   24V954  RIONL-24V954-1052.pdf      LINCOLN              CORSAIR
# 6911   24V954   RCMN-24V954-8927.pdf      LINCOLN              CORSAIR
# 6912   24V954  RIONL-24V954-2080.pdf      LINCOLN              CORSAIR
# 6913   24V954  RMISC-24V954-7770.pdf      LINCOLN              CORSAIR
# 6914   24V962   RCMN-24V962-3806.pdf          KIA                  EV9
# 6915   24V962  RCRIT-24V962-7747.pdf          KIA                  EV9
# 6916   24V962  RCONL-24V962-1772.pdf          KIA                  EV9
# 6917   24V962   RCMN-24V962-3299.pdf          KIA                  EV9
# 6918   24V962   RCMN-24V962-3393.pdf          KIA                  EV9
#
#       MODEL YEAR                                            SUMMARY
# 6860        2024  Copy of reimbursement plan for customers who h...
# 6861        2024                       Customer notification letter
# 6862        2024                       Customer notification letter
# 6863        2024  Manufacturer notification of safety recall to ...
# 6864        2024                      Stop sales notice to dealers.
# 6865        2024  Example customer notification letter content f...
# 6866        2024                                  Parts order form.
# 6867        2024                    Chronology of principal events.
# 6868        2024            Remedy instructions and TSB to dealers.
# 6869        2024  Dealer Combo regarding certain 2024 Model Year...
# 6870        2024  Final Owner Letter regarding certain 2024 Mode...
# 6871        2024  NSRAC regarding certain 2024 model year Jeep G...
# 6872        2024  Final Owner Letter regarding certain 2024 Mode...
# 6873        2024  Dealer Combo regarding certain 2024 Model Year...
# 6874        2024  NSRAC regarding certain 2024 model year Jeep G...
# 6875        2024             This is the parts bulletin for R10296.
# 6876        2024           This is the Quality Bulletin for R10296.
# 6877        2024            This is the retailer letter for R10296.
# 6878        2024  NSRAC regarding certain 2024 model year Jeep W...
# 6879        2024  Dealer Combo regarding certain 2024 model year...
# 6880        2024  Revised NSRAC regarding certain 2024 model yea...
# 6881        2024  Final Owner Letter regarding certain 2024 mode...
# 6882        2024  Dealer Combo regarding certain 2024 model year...
# 6883        2024  NSRAC regarding certain 2024 model year Jeep W...
# 6884        2024  Revised NSRAC regarding certain 2024 model yea...
# 6885        2024  Final Owner Letter regarding certain 2024 mode...
# 6886        2024  Final Owner Letter regarding certain 2024 mode...
# 6887        2024  Dealer Combo regarding certain 2024 model year...
# 6888        2024  NSRAC regarding certain 2024 model year Jeep W...
# 6889        2024  Revised NSRAC regarding certain 2024 model yea...
# 6890        2024  Revised NSRAC regarding certain 2024 model yea...
# 6891        2024  Final Owner Letter regarding certain 2024 mode...
# 6892        2024  NSRAC regarding certain 2024 model year Jeep W...
# 6893        2024  Dealer Combo regarding certain 2024 model year...
# 6894        2024  Customer letter informing about the issue, ris...
# 6895        2024  Technical Service Bulletin with repair instruc...
# 6896        2024  Letter to the dealer network in order to infor...
# 6897        2024  24S76 Parts available owner letter.  Mailed Fe...
# 6898        2024  NEW VEHICLE DEMONSTRATION / DELIVERY HOLD -\nS...
# 6899        2024  NEW VEHICLE DEMONSTRATION / DELIVERY HOLD - Ad...
# 6900        2024  NEW VEHICLE DEMONSTRATION / DELIVERY HOLD - Ad...
# 6901        2024  24C43 Interim owner letter.  Mailed February 1...
# 6902        2024  24C43 Parts available owner letter.  Mailed Fe...
# 6903        2024  NEW VEHICLE DEMONSTRATION / DELIVERY HOLD - Co...
# 6904        2024  24S79 Customer email and Ford Pass App Feb 21,...
# 6905        2024  NEW VEHICLE DEMONSTRATION / DELIVERY HOLD - Ad...
# 6906        2024  REF:NEW VEHICLE DEMONSTRATION / DELIVERY HOLD ...
# 6907        2024  24S79 Interim owner letter.  Mailed January 15...
# 6908        2024  24S79 Interim owner letter.  Mailed February 1...
# 6909        2024  NEW VEHICLE DEMONSTRATION / DELIVERY HOLD - Ad...
# 6910        2024  24S79 Interim owner letter.  Mailed January 15...
# 6911        2024  REF:NEW VEHICLE DEMONSTRATION / DELIVERY HOLD ...
# 6912        2024  24S79 Interim owner letter.  Mailed February 1...
# 6913        2024  24S79 Customer email and Ford Pass App Feb 21,...
# 6914        2024  The Q&A contains questions and answers regardi...
# 6915        2024  The Technical Service Bulletin (TSB) lists spe...
# 6916        2024  Owner Letter notifies the customer of the safe...
# 6917        2024  The Dealer Parts & Service Manager letter is t...
# 6918        2024  The Dealer Principal letter is to notify the d...
