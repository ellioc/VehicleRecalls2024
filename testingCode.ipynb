# %%
import pandas 
import matplotlib
import seaborn

import pandas as pd
df1 = pd.read_csv("vehicles_dataset.csv")


import pandas as pd
df2 = pd.read_csv("RCL_FROM_2020_2024.csv")

# %%
pd.set_option('display.max_columns', None)

df_CarList = pd.read_csv("vehicles_dataset.csv")
df_CarList.info(max_cols=20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1002 entries, 0 to 1001
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            1002 non-null   object
#  1   description     946 non-null    object
#  2   make            1002 non-null   object
#  3   model           1002 non-null   object
#  4   type            1002 non-null   object
#  5   year            1002 non-null   int64
#  6   price           979 non-null    float64
#  7   engine          1000 non-null   object
#  8   cylinders       897 non-null    float64
#  9   fuel            995 non-null    object
#  10  mileage         968 non-null    float64
#  11  transmission    1000 non-null   object
#  12  trim            1001 non-null   object
#  13  body            999 non-null    object
#  14  doors           995 non-null    float64
#  15  exterior_color  997 non-null    object
#  16  interior_color  964 non-null    object
# ...

# %% [markdown]
# Removing unwanted columns from dataset

# %%
df_CarList.drop_duplicates()


df_CarList.drop(columns= ['description','fuel','type','engine','interior_color','exterior_color','mileage','doors'])
# Out:
#                                                 name           make  \
# 0                       2024 Jeep Wagoneer Series II           Jeep
# 1                    2024 Jeep Grand Cherokee Laredo           Jeep
# 2                           2024 GMC Yukon XL Denali            GMC
# 3                         2023 Dodge Durango Pursuit          Dodge
# 4                              2024 RAM 3500 Laramie            RAM
# ...                                              ...            ...
# 997   2024 Mercedes-Benz Sprinter 2500 Standard Roof  Mercedes-Benz
# 998           2024 Dodge Hornet Hornet R/T Plus Eawd          Dodge
# 999                          2024 Jeep Wagoneer Base           Jeep
# 1000           2024 Nissan Murano SV Intelligent AWD         Nissan
# 1001                2024 Chevrolet Silverado 2500 WT      Chevrolet
#
#                model  year    price  cylinders  \
# 0           Wagoneer  2024  74600.0        6.0
# 1     Grand Cherokee  2024  50170.0        6.0
# ...

# %%
import sqlite3
.mode csv
# Out:
#   Cell In[37], line 2
#     .mode csv
#     ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

def head_in_tail(df, n=5):

    if len(df) <= 2 * n:
        return df
    else:
        return pd.concat([df.head(n), df.tail(n)])
print (df1)
# Out:
#                                                 name  \
# 0                       2024 Jeep Wagoneer Series II
# 1                    2024 Jeep Grand Cherokee Laredo
# 2                           2024 GMC Yukon XL Denali
# 3                         2023 Dodge Durango Pursuit
# 4                              2024 RAM 3500 Laramie
# ...                                              ...
# 997   2024 Mercedes-Benz Sprinter 2500 Standard Roof
# 998           2024 Dodge Hornet Hornet R/T Plus Eawd
# 999                          2024 Jeep Wagoneer Base
# 1000           2024 Nissan Murano SV Intelligent AWD
# 1001                2024 Chevrolet Silverado 2500 WT
#
#                                             description           make  \
# 0     \n      \n        Heated Leather Seats, Nav Sy...           Jeep
# 1     Al West is committed to offering every custome...           Jeep
# 2                                                   NaN            GMC
# ...

# %%
df1.isnull().sum()
# Out:
# name                0
# description        56
# make                0
# model               0
# type                0
# year                0
# price              23
# engine              2
# cylinders         105
# fuel                7
# mileage            34
# transmission        2
# trim                1
# body                3
# doors               7
# exterior_color      5
# interior_color     38
# drivetrain          0
# dtype: int64
